# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("enterprise_supply_chain_dataset.csv")
df.head()
# Out:
#    Order_ID  Order_Date Delivery_Date Region Country       City Product_Name  \
# 0  ORD00001  2025-10-16    2025-10-19   West   India  Hyderabad       Laptop
# 1  ORD00002  2025-06-01    2025-06-12  North     USA  Bangalore       Tablet
# 2  ORD00003  2024-08-08    2024-08-24  North     UAE  Hyderabad      Printer
# 3  ORD00004  2025-09-25    2025-10-12  North     UAE      Delhi      Monitor
# 4  ORD00005  2025-01-14    2025-01-22  South     UAE  Bangalore       Tablet
#
#   Supplier_Name    Warehouse  Order_Quantity  ...  Reorder_Level  \
# 0    Supplier B  Warehouse 1              48  ...            119
# 1    Supplier C  Warehouse 1              36  ...            125
# 2    Supplier C  Warehouse 3               7  ...             55
# 3    Supplier C  Warehouse 1              37  ...             60
# 4    Supplier B  Warehouse 3              43  ...             71
#
#    Stockout_Flag  Defect_Rate  Order_Status  Delivery_Days  Profit_Margin  \
# ...

# %%
df.shape
# Out:
# (1000, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            1000 non-null   object
#  1   Order_Date          1000 non-null   object
#  2   Delivery_Date       1000 non-null   object
#  3   Region              1000 non-null   object
#  4   Country             1000 non-null   object
#  5   City                1000 non-null   object
#  6   Product_Name        1000 non-null   object
#  7   Supplier_Name       1000 non-null   object
#  8   Warehouse           1000 non-null   object
#  9   Order_Quantity      1000 non-null   int64
#  10  Unit_Price          1000 non-null   int64
#  11  Revenue             1000 non-null   int64
#  12  Shipping_Cost       1000 non-null   float64
#  13  Manufacturing_Cost  1000 non-null   float64
#  14  Profit              1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Order_Quantity   Unit_Price       Revenue  Shipping_Cost  \
# count      1000.00000  1000.000000   1000.000000    1000.000000
# mean         25.77700  1027.474000  26534.461000    1971.018530
# std          14.69596   540.579083  21906.864487    1824.303613
# min           1.00000   100.000000    223.000000      20.060000
# 25%          12.00000   539.000000   9015.750000     588.885000
# 50%          25.00000  1016.000000  20107.500000    1407.745000
# 75%          39.00000  1480.250000  39024.000000    2853.992500
# max          50.00000  1990.000000  96187.000000   10500.810000
#
#        Manufacturing_Cost        Profit  Lead_Time_Days  Inventory_Level  \
# count         1000.000000   1000.000000      1000.00000      1000.000000
# mean         14468.095600  10095.346870         8.29500       252.216000
# std          12276.632709   8890.665825         4.03488       141.479043
# min            121.460000     76.110000         2.00000         2.000000
# ...

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Delivery_Date', 'Region', 'Country', 'City',
#        'Product_Name', 'Supplier_Name', 'Warehouse', 'Order_Quantity',
#        'Unit_Price', 'Revenue', 'Shipping_Cost', 'Manufacturing_Cost',
#        'Profit', 'Lead_Time_Days', 'Inventory_Level', 'Reorder_Level',
#        'Stockout_Flag', 'Defect_Rate', 'Order_Status', 'Delivery_Days',
#        'Profit_Margin', 'Delay_Flag', 'Order_Month', 'Order_Year',
#        'Inventory_Status'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Order_ID              0
# Order_Date            0
# Delivery_Date         0
# Region                0
# Country               0
# City                  0
# Product_Name          0
# Supplier_Name         0
# Warehouse             0
# Order_Quantity        0
# Unit_Price            0
# Revenue               0
# Shipping_Cost         0
# Manufacturing_Cost    0
# Profit                0
# Lead_Time_Days        0
# Inventory_Level       0
# Reorder_Level         0
# Stockout_Flag         0
# Defect_Rate           0
# Order_Status          0
# Delivery_Days         0
# Profit_Margin         0
# Delay_Flag            0
# Order_Month           0
# Order_Year            0
# Inventory_Status      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])
df["Delivery_Date"] = pd.to_datetime(df["Delivery_Date"])

# %%
df["Delivery_Days"] = (
    df["Delivery_Date"] - df["Order_Date"]
).dt.days

# %%
df["Profit_Margin"] = (
    df["Profit"] / df["Revenue"]
) * 100

# %%
df["Delay_Flag"] = np.where(
    df["Delivery_Days"] > 10,
    "Delayed",
    "On Time"
)

# %%
df["Order_Month"] = df["Order_Date"].dt.month_name()

# %%
df["Order_Year"] = df["Order_Date"].dt.year

# %%
df["Inventory_Status"] = np.where(
    df["Inventory_Level"] < df["Reorder_Level"],
    "Low Stock",
    "Sufficient"
)

# %%
df["Revenue"].sum()
# Out:
# np.int64(26534461)

# %%
df["Profit"].sum()
# Out:
# np.float64(10095346.870000001)

# %%
df["Lead_Time_Days"].mean()
# Out:
# np.float64(8.295)

# %%
df["Stockout_Flag"].value_counts()
# Out:
# Stockout_Flag
# No     811
# Yes    189
# Name: count, dtype: int64

# %%
df["Order_Status"].value_counts()
# Out:
# Order_Status
# In Transit    268
# Delivered     260
# Cancelled     249
# Pending       223
# Name: count, dtype: int64

# %%
df.groupby("Supplier_Name")["Profit"].sum()
# Out:
# Supplier_Name
# Supplier A    2748947.34
# Supplier B    2245179.34
# Supplier C    2496043.38
# Supplier D    2605176.81
# Name: Profit, dtype: float64

# %%
df.groupby("Product_Name")["Revenue"].sum().sort_values(ascending=False)
# Out:
# Product_Name
# Monitor     5113486
# Tablet      4564216
# Laptop      4379097
# Phone       4349710
# Keyboard    4257047
# Printer     3870905
# Name: Revenue, dtype: int64

# %%
df.groupby("Warehouse")["Revenue"].sum()
# Out:
# Warehouse
# Warehouse 1    8648493
# Warehouse 2    8533084
# Warehouse 3    9352884
# Name: Revenue, dtype: int64

# %%
df.to_csv("cleaned_supply_chain_data.csv", index=False)
